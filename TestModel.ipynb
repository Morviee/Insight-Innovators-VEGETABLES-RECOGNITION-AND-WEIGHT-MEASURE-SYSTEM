# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as pl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Vegetable Images/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 3000 files belonging to 15 classes.

# %%
cnn = tf.keras.models.load_model('/content/drive/MyDrive/trained_model.h5')

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)

# %%
import matplotlib.pyplot as plt
import cv2
image_path = '/content/drive/MyDrive/Vegetable Images/test/Cabbage/0929.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 480ms/step

# %%
print(predictions)
# Out:
# [[7.5607021e-12 4.2137993e-10 8.1185414e-15 3.1880251e-10 3.0834492e-08
#   1.0000000e+00 7.1820457e-15 2.5139333e-22 1.1214674e-10 2.0628015e-09
#   2.5870018e-13 1.3383711e-17 2.0597839e-11 1.9920980e-18 2.4211072e-13]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 5

# %%
image_path = '/content/drive/MyDrive/Vegetable Images/test/Broccoli/1006.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
print(predictions)
# Out:
# [[8.9985691e-03 1.8093402e-02 1.9931939e-08 6.4301407e-06 9.4562352e-01
#   4.9941133e-05 1.7475008e-08 4.8986291e-09 1.2552601e-04 9.9913696e-06
#   2.6065325e-07 2.2884849e-07 1.7688707e-04 2.5969339e-08 2.6915289e-02]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 4

# %%
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a Broccoli
